# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.

# %%
img=cv2.imread(r'C:\Users\SIDDARTH\Desktop\Image_classification_project\test_images\sharapova1.jpg')
img.shape
# Out:
# (555, 700, 3)

# %%
plt.imshow(img)

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml') # for detecting faces
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')  # for detecting eyes

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(plt.imshow(gray,cmap='gray'))
# Out:
# AxesImage(54,36;334.8x217.44)
# array([[352,  38, 233, 233]], dtype=int32)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces  # it return x-axis y-axis width height
# Out:
# array([[352,  38, 233, 233]], dtype=int32)

# %%
#### Now to detect eyes 
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)  # draw red rectangle around face
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)    
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2) # draw green rect around eyes
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
############## Now the pic needs to be cropped as we need only face, cropped image is roi_color
plt.imshow(roi_color)

# %% [markdown]
# ######                 Main code to clean and crop input image dataset

# %%
## taking only those image in which face and 2 eyes are detected
def get_cropped_images(image_path):
    img=cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
image_dataset='../images_dataset/'
clean_croped_data='./clean_crop_dataset/'

# %%
import os
img_dirs = []
for entry in os.scandir(image_dataset):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['../images_dataset/lionel_messi',
#  '../images_dataset/maria_sharapova',
#  '../images_dataset/roger_federer',
#  '../images_dataset/serena_williams',
#  '../images_dataset/virat_kohli']

# %%
import shutil
if os.path.exists(clean_croped_dataset):
    shutil.remove(clean_croped_dataset)
os.mkdir(clean_croped_dataset)

# %%
cropped_image_dirs = []
# celebrity_file_names_dict = {}

for entry in img_dirs:
#     print(entry)
    count = 1
    f = entry.split('/')[-1]
    celebrity_file_names_dict[f]=[]
    for file in os.scandir(entry):
        ima = get_cropped_images(file.path)
        if ima is not None:
            crop_folder = clean_croped_data + f
            if not os.path.exists(crop_folder):
                os.mkdir(crop_folder)
                cropped_image_dirs.append(crop_folder)
                
            file_name_path = crop_folder + "/" + f + "_" + str(count) +'.png'  # path and of cropped file to save at
            count += 1
            cv2.imwrite(file_name_path, ima)
#             celebrity_file_names_dict[f].append(file_name_path)

# %%
cropped_image_dirs
# Out:
# ['./clean_crop_dataset/lionel_messi',
#  './clean_crop_dataset/maria_sharapova',
#  './clean_crop_dataset/roger_federer',
#  './clean_crop_dataset/serena_williams',
#  './clean_crop_dataset/virat_kohli']

# %%
crop_image_path={}
for f in cropped_image_dirs:
    name = f.split('/')[-1]
    crop_image_path[name] = []
    for entry in os.scandir(f):
        crop_image_path[name].append(entry.path)

# %%
crop_image_path
# Out:
# {'lionel_messi': ['./clean_crop_dataset/lionel_messi\\lionel_messi_1.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_10.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_11.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_13.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_14.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_15.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_16.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_17.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_18.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_19.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_2.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_20.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_22.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_23.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_24.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_25.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_26.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_27.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_28.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_29.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_3.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_30.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_32.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_33.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_34.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_35.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_36.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_37.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_38.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_39.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_4.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_5.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_6.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_7.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_8.png',
#   './clean_crop_dataset/lionel_messi\\lionel_messi_9.png'],
#  'maria_sharapova': ['./clean_crop_dataset/maria_sharapova\\maria_sharapova_10.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_14.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_15.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_16.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_17.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_18.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_19.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_2.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_20.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_21.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_22.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_24.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_25.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_26.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_27.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_28.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_29.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_30.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_31.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_32.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_33.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_34.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_35.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_4.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_5.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_6.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_7.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_8.png',
#   './clean_crop_dataset/maria_sharapova\\maria_sharapova_9.png'],
#  'roger_federer': ['./clean_crop_dataset/roger_federer\\roger_federer_1.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_10.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_11.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_12.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_13.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_14.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_15.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_16.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_17.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_18.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_19.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_2.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_20.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_21.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_22.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_23.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_24.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_25.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_28.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_29.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_3.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_30.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_4.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_5.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_6.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_7.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_8.png',
#   './clean_crop_dataset/roger_federer\\roger_federer_9.png'],
#  'serena_williams': ['./clean_crop_dataset/serena_williams\\serena_williams_10.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_12.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_13.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_14.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_15.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_17.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_2.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_20.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_22.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_23.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_24.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_26.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_27.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_28.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_29.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_3.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_30.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_31.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_32.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_34.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_4.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_5.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_6.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_7.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_8.png',
#   './clean_crop_dataset/serena_williams\\serena_williams_9.png'],
#  'virat_kohli': ['./clean_crop_dataset/virat_kohli\\virat_kohli_1.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_10.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_11.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_12.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_13.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_14.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_15.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_16.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_17.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_18.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_19.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_2.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_20.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_21.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_23.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_25.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_26.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_27.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_28.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_30.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_31.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_32.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_33.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_35.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_36.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_37.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_38.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_39.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_4.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_40.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_41.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_42.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_44.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_45.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_47.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_48.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_5.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_6.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_7.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_8.png',
#   './clean_crop_dataset/virat_kohli\\virat_kohli_9.png']}

# %%
######################################## ---------------------- ###########################################################

# %% [markdown]
# ###  (3) Preprocessing: Use wavelet transform as a feature for traning our model
#
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc
#
# #### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
## You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. 
## This along with raw pixel image can be used as an input for our classifier
im_har = w2d(roi_color,'db1',5)
# print(im_har)
plt.imshow(im_har, cmap='gray')
# Out:
# [[229 229 229 ... 204 204 204]
#  [229 229 229 ... 204 204 204]
#  [229 229 214 ...  59 204 204]
#  ...
#  [ 23  23 204 ...  27 236 236]
#  [ 23  23  23 ... 236 236 236]
#  [ 23  23  23 ... 236 236 236]]

# %%
class_dict = {}
count = 0
for celebrity_name in crop_image_path.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %%
x=[]
y=[]
for i in crop_image_path:
    for j in crop_image_path[i]:
        img=cv2.imread(j)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        x.append(combined_img)
        y.append(class_dict[i])

# %%
len(x[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
x = np.array(x).reshape(len(x),4096).astype(float)
x.shape
# Out:
# (160, 4096)

# %%
####################### ---------------- Now we are ready for Model creation and training --------------- #################

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
# scaler=StandardScaler()
# x_train_transformed = scaler.fit_transform(x_train)


pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
print(pipe)
pipe.fit(x_train, y_train)
pipe.score(x_test, y_test)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=10, break_ties=False, cache_size=200, class_weight=None,
#                      coef0=0.0, decision_function_shape='ovr', degree=3,
#                      gamma='scale', kernel='rbf', max_iter=-1,
#                      probability=False, random_state=None, shrinking=True,
#                      tol=0.001, verbose=False))],
#          verbose=False)
# 0.825

# %%
################### performing Grid-Search (Parameter tuning and model selection) ############################################
